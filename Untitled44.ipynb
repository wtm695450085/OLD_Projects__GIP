# %%
from cvxopt import matrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-66dd81eb606b> in <module>
# ----> 1 from cvxopt import matrix
#
# ModuleNotFoundError: No module named 'cvxopt'

# %%
# !pip install gekko
# Out:
# Collecting gekko
#   Downloading https://files.pythonhosted.org/packages/da/50/2789ce0facf9c6ce6275f3246f8fe82df40ea96a9173be70bf8128ee62df/gekko-0.2.6-py3-none-any.whl (9.8MB)
#      |████████████████████████████████| 9.8MB 666kB/s eta 0:00:01
# Collecting flask-cors (from gekko)
#   Downloading https://files.pythonhosted.org/packages/78/38/e68b11daa5d613e3a91e4bf3da76c94ac9ee0d9cd515af9c1ab80d36f709/Flask_Cors-3.0.8-py2.py3-none-any.whl
# Requirement already satisfied: flask in ./anaconda3/lib/python3.7/site-packages (from gekko) (1.1.1)
# Requirement already satisfied: numpy>=1.8 in ./anaconda3/lib/python3.7/site-packages (from gekko) (1.17.2)
# Requirement already satisfied: Six in ./anaconda3/lib/python3.7/site-packages (from flask-cors->gekko) (1.12.0)
# Requirement already satisfied: Jinja2>=2.10.1 in ./anaconda3/lib/python3.7/site-packages (from flask->gekko) (2.10.3)
# Requirement already satisfied: itsdangerous>=0.24 in ./anaconda3/lib/python3.7/site-packages (from flask->gekko) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in ./anaconda3/lib/python3.7/site-packages (from flask->gekko) (0.16.0)
# Requirement already satisfied: click>=5.1 in ./anaconda3/lib/python3.7/site-packages (from flask->gekko) (7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in ./anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10.1->flask->gekko) (1.1.1)
# Installing collected packages: flask-cors, gekko
# Successfully installed flask-cors-3.0.8 gekko-0.2.6

# %%
from scipy.optimize import linprog

# %%
from gekko import GEKKO
m = GEKKO()
x1 = m.Var(lb=0, ub=5) # Product 1
x2 = m.Var(lb=0, ub=4) # Product 2
m.Maximize(100*x1+125*x2) # Profit function
m.Equation(3*x1+6*x2<=30) # Units of A
m.Equation(8*x1+4*x2<=44) # Units of B
m.solve(disp=False)
p1 = x1.value[0]; p2 = x2.value[0]
print ('Product 1 (x1): ' + str(p1))
print ('Product 2 (x2): ' + str(p2))
print ('Profit        : ' + str(100*p1+125*p2))
# Out:
# Product 1 (x1): 4.0
# Product 2 (x2): 3.0000000014
# Profit        : 775.000000175

# %% [markdown]
# \begin{align}
# {f(x)} & = 10 - 2x \\
# {f(x)} & = 6 - x \\
# {f(x)} & = 4 + x
# \end{align}

# %%
import numpy as np
import matplotlib.pyplot as plt

d = np.linspace(0, 10)

plt.plot(d, 10 - 2 * d, d, 6 - d, d, 4 + d)
plt.ylim([0, 10])
plt.xticks(np.arange(0, 10))
plt.yticks(np.arange(0, 10))
plt.legend(['f(x) = 10 - 2x', 'f(x) = 6 - x', 'f(x) = 4 + x'])
plt.show()

# %%
y = (96000-(16*x))/24

# %%
y = (80000-(16*x))/10

# %%
y = (2/3)*x

# %%
x = 3000
y = 4000

# %%
import numpy as np
import matplotlib.pyplot as plt

d = np.linspace(0, 100000)

plt.plot(d, (96000-(16*d))/24, d, (80000-(16*d))/10, d, (2/3)*d)
plt.ylim([0, 10])
plt.xticks(np.arange(0, 100000))
plt.yticks(np.arange(0, 80000))
plt.legend(['f(x) = 10 - 2x', 'f(x) = 6 - x', 'f(x) = 4 + x'])
plt.show()

# %% [markdown]
# $$
# \left\{
# \begin{array}{c}
# a_1x+b_1y+c_1z=d_1 \\
# a_2x+b_2y+c_2z=d_2 \\
# a_3x+b_3y+c_3z=d_3
# \end{array}
# \right.
# $$

# %% [markdown]
# PRZYKŁAD 2  STR 20![obraz.png](attachment:obraz.png)

# %% [markdown]
# $$
# \left\{
# \begin{align}
# {6x+6y}  & \leqslant 36000 \\
# {10x+5y} & \leqslant 50000 \\
# {x} & \geqslant 0 \\
# {0} & \leqslant x \leqslant 4000 \\
# \end{align}
# \right.
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# plot the feasible region
d = np.linspace(-2,6000,100)
x,y = np.meshgrid(d,d)
plt.imshow( (((6*x)+(6*y)<=36000) & ((10*x)+(5*y)<=50000) & (x>=0) & (y<=4000)&(y>=0)).astype(int) , 
                extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greys", alpha = 0.3);


# plot the lines defining the constraints
x = np.linspace(0, 6000, 10)
# 6x+6y<=36000
y1 = ((36000-(6*x))/6)
# 10x+5y <= 36000
y2 = (50000-(10*x))/5
# x >= 0 
y3 = (x*0)
# y <= 4000 
y4 = (x*0)+4000 #ok
# y>=0
y5 =(x*0)       #ok

# Make plot
plt.plot(x, y1, label=r'$(36000-(6*x))/6$')
plt.plot(x, y2, label=r'$(36000-(10*x))/5$')
plt.plot(x, y3, label=r'$y3 =0$')
plt.plot(x, y4, label=r'$y4 = 4000$')
plt.plot(x, y5, label=r'$y5 = 0$')
plt.xlim(0,6000)
plt.ylim(0,6000)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# ZADANIE 1 STR. 26
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# $$
# \left\{
# \begin{align}
# {3x+y}  & \leqslant 33 000 \\
# {x+y} & \leqslant 13 000 \\
# {5x+8y} & \leqslant 80 000 \\
# {x} & \leqslant 7 000 \\
# \end{align}
# \right.
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# plot the feasible region
d = np.linspace(-2,12000,100)
x,y = np.meshgrid(d,d)
plt.imshow( (((3*x)+(y)<=33000) & (x+y<=13000) & ((5*x)+(8*y)<=80000) & (y<=7000)).astype(int) , 
                extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greys", alpha = 0.3);


# plot the lines defining the constraints
x = np.linspace(0, 12000, 10)
# 6x+6y<=36000
y1 = 33000-(3*x)
# 10x+5y <= 36000
y2 = 13000-x
# x >= 0 
y3 = (80000-(5*x))/8
# y <= 4000 
y4 = (x*0)+7000 
# y>=0
#y5 = x/4  
#y6 = x*(1/3)

# Make plot
plt.plot(x, y1, label=r'$y1 = 33000-(3*x)$')
plt.plot(x, y2, label=r'$y2 = 13000-x$')
plt.plot(x, y3, label=r'$y3 = (80000-(5*x))/8$')
plt.plot(x, y4, label=r'$y4 = 4000$')
#plt.plot(x, y5, label=r'$y5 = x/4$')
#plt.plot(x, y6, label=r'$y5 = x/4$')
plt.xlim(0,12000)
plt.ylim(0,12000)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# 1. Ponieważ zysk ze sprzedaży wyrobu y jest 3 razy większy niż zysk z wyrobu x, trzeba produkować maksymalne ilości wyrobu y.
# 2. wyrobu y nie można produkować więcej niż 7000 sztuk - to przy ilości max y=7000 sztuk szukamy na wykresie punktu max ilości wyrobu x
#
# Ten punkt to: x = 4800 i y = 7000

# %%
g = (7000*3)+(4800*1)
print('Zysk maksymalny:',g)
# Out:
# Zysk maksymalny: 25800

# %%
Jeżeli zysk ze sprzedaży x wzrośnie z 1 zł do 4 zł.
Maksymulalizujemy tym razem wyrób x
x = 10000, y = 3000 to róg naszego szarego obszaru

ROGI SZAREGO OBSZARU TO SĄ OPTIMA LOKALNE.

# %% [markdown]
# ZADANIE 2 STR. 26
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# $$
# \left\{
# \begin{align}
# {16x+24y}  & \leqslant 96000 \\
# {16x+10y} & \leqslant 80000 \\
# {y} & = (2/3)x \\
# {x} & \leqslant 3000 \\
# \end{align}
# \right.
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# plot the feasible region
d = np.linspace(-2,6000,100)
x,y = np.meshgrid(d,d)
plt.imshow( (((16*x)+(24*y)<=96000) & ((16*x)+(10*y)<=80000) &  (x<=3000) & (x>=0) & (y<=4000) & (y>=0)).astype(int) , 
                extent=(x.min(),x.max(),y.min(),y.max()),origin="lower", cmap="Greys", alpha = 0.3);


# plot the lines defining the constraints
x = np.linspace(0, 8000, 10)
# 6x+6y<=36000
y1 = (96000-(16*x))/24
# 10x+5y <= 36000
y2 = (80000-(16*x))/10
# x >= 0 
y3 = 0.6*x
# y <= 4000 
y4 = (x*0)+4000 
# y>=0
y5 = x-3000 
#y6 = x*(1/3)   

# Make plot
plt.plot(x, y1, label=r'$y1 = 33000-(3*x)$')
plt.plot(x, y2, label=r'$y2 = 13000-x$')
plt.plot(x, y3, label=r'$y3 = (80000-(5*x))/8$')
plt.plot(x, y4, label=r'$y4 = 4000$')
plt.plot(x, y5, label=r'$y5 = x/4$')
#plt.plot(x, y6, label=r'$y5 = x/4$')
#plt.xlim(0,12000)
#plt.ylim(0,12000)
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.xlabel(r'$x$')
#plt.ylabel(r'$y$')

# %%
from cvxopt import matrix, solvers
A = matrix([ [-1.0, -1.0, 0.0, 1.0], [1.0, -1.0, -1.0, -2.0] ])
b = matrix([ 1.0, -2.0, 0.0, 4.0 ])
c = matrix([ 2.0, 1.0 ])
sol=solvers.lp(c,A,b)
# Out:
#      pcost       dcost       gap    pres   dres   k/t
#  0:  2.6471e+00 -7.0588e-01  2e+01  8e-01  2e+00  1e+00
#  1:  3.0726e+00  2.8437e+00  1e+00  1e-01  2e-01  3e-01
#  2:  2.4891e+00  2.4808e+00  1e-01  1e-02  2e-02  5e-02
#  3:  2.4999e+00  2.4998e+00  1e-03  1e-04  2e-04  5e-04
#  4:  2.5000e+00  2.5000e+00  1e-05  1e-06  2e-06  5e-06
#  5:  2.5000e+00  2.5000e+00  1e-07  1e-08  2e-08  5e-08
# Optimal solution found.

# %%
print(A)
# Out:
# [-1.00e+00  1.00e+00]
# [-1.00e+00 -1.00e+00]
# [ 0.00e+00 -1.00e+00]
# [ 1.00e+00 -2.00e+00]

# %%
print(b)
# Out:
# [ 1.00e+00]
# [-2.00e+00]
# [ 0.00e+00]
# [ 4.00e+00]
